# %%
import pandas as pd

# %%
import pandas as pd

# Carregar os dados
df = pd.read_csv('car_prices.csv')  # Substitua pelo caminho correto do ficheiro

# Contar quantos modelos únicos existem
num_modelos = df["state"].nunique()

# Mostrar a lista de modelos únicos (opcional)
modelos_unicos = df["state"].unique()

print(f"Número total de modelos diferentes: {num_modelos}")
print("Lista de modelos únicos:")
print(modelos_unicos)
df
# Out:
# Número total de modelos diferentes: 64
# Lista de modelos únicos:
# ['ca' 'tx' 'pa' 'mn' 'az' 'wi' 'tn' 'md' 'fl' 'ne' 'nj' 'nv' 'oh' 'mi'
#  'ga' 'va' 'sc' 'nc' 'in' 'il' 'co' 'ut' 'mo' 'ny' 'ma' 'pr' 'or' 'la'
#  'wa' 'hi' 'qc' 'ab' 'on' 'ok' 'ms' 'nm' 'al' '3vwd17aj4fm201708' 'ns'
#  '3vwd17aj2fm258506' '3vwd17aj3fm276741' '3vwd17aj2fm285365'
#  '3vwd17aj0fm227318' '3vwd17aj6fm218641' '3vwd17aj7fm223475'
#  '3vwd17aj5fm297123' '3vwd17aj5fm219943' '3vwd17aj9fm219766'
#  '3vwd17aj3fm259017' '3vwd17aj5fm206111' '3vwd17aj5fm273601'
#  '3vwd17aj5fm221322' '3vwd17aj5fm268964' '3vwd17aj6fm231972'
#  '3vwd17aj7fm222388' '3vwd17aj7fm218440' '3vwd17ajxfm315938'
#  '3vwd17aj7fm229552' '3vwd17aj8fm298895' '3vwd17aj4fm236636'
#  '3vwd17aj5fm225953' '3vwd17aj7fm326640' '3vwd17aj8fm239622'
#  '3vwd17aj2fm261566']
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# ...

# %%
import pandas as pd

# Carregar os dados
df = pd.read_csv('car_prices.csv')  # Substitua pelo caminho correto do ficheiro

# Lista dos valores a remover
valores_a_remover = [
    '3vwd17aj4fm201708', 'ns', '3vwd17aj2fm258506', '3vwd17aj3fm276741',
    '3vwd17aj2fm285365', '3vwd17aj0fm227318', '3vwd17aj6fm218641', '3vwd17aj7fm223475',
    '3vwd17aj5fm297123', '3vwd17aj5fm219943', '3vwd17aj9fm219766', '3vwd17aj3fm259017',
    '3vwd17aj5fm206111', '3vwd17aj5fm273601', '3vwd17aj5fm221322', '3vwd17aj5fm268964',
    '3vwd17aj6fm231972', '3vwd17aj7fm222388', '3vwd17aj7fm218440', '3vwd17ajxfm315938',
    '3vwd17aj7fm229552', '3vwd17aj8fm298895', '3vwd17aj4fm236636', '3vwd17aj5fm225953',
    '3vwd17aj7fm326640', '3vwd17aj8fm239622', '3vwd17aj2fm261566'
]

# Remover as linhas onde a coluna "state" contém os valores indesejados
df = df[~df["state"].isin(valores_a_remover)]

# Guardar o novo ficheiro sem essas linhas
df.to_csv("car_prices_clean.csv")
print("Linhas removidas com sucesso. Ficheiro atualizado salvo como 'car_prices_limpo.csv'.")
# Out:
# Linhas removidas com sucesso. Ficheiro atualizado salvo como 'car_prices_limpo.csv'.

# %%
import pandas as pd

# Carregar os dados
df = pd.read_csv('car_prices_clean.csv')  # Substitua pelo caminho correto do ficheiro

# Remover linhas com valores NaN
df = df.dropna()

# Guardar o novo ficheiro sem linhas com NaN
df.to_csv('car_prices_sem_na.csv', index=False)

print("Linhas com valores NaN removidas. Ficheiro atualizado salvo como 'car_prices_sem_na.csv'.")
# Out:
# Linhas com valores NaN removidas. Ficheiro atualizado salvo como 'car_prices_sem_na.csv'.

# %%
df.to_csv('car_prices_sem_na.csv', index=False)
df
# Out:
#         Unnamed: 0  year    make                model         trim       body  \
# 0                0  2015     Kia              Sorento           LX        SUV
# 1                1  2015     Kia              Sorento           LX        SUV
# 2                2  2014     BMW             3 Series   328i SULEV      Sedan
# 3                3  2015   Volvo                  S60           T5      Sedan
# 4                4  2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...            ...   ...     ...                  ...          ...        ...
# 558744      558831  2011     BMW             5 Series         528i      Sedan
# 558746      558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558747      558834  2012     BMW                   X5    xDrive35d        SUV
# 558748      558835  2015  Nissan               Altima        2.5 S      sedan
# 558749      558836  2014    Ford                F-150          XLT  SuperCrew
#
# ...

# %%
df.to_csv('car_prices_sem_na.csv', index=False)

unique_values = df[['make', 'model']].drop_duplicates()
num_unique = unique_values.shape[0]
print(num_unique)

unique_values.to_csv("ruben.csv", index=False)
# Out:
# 776

# %%
modelos_unicos = df["state"].unique()
modelos_unicos
# Out:
# array(['ca', 'tx', 'mn', 'az', 'wi', 'tn', 'md', 'pa', 'fl', 'ne', 'oh',
#        'mi', 'nj', 'va', 'sc', 'in', 'il', 'co', 'ut', 'mo', 'ga', 'nv',
#        'ma', 'pr', 'nc', 'ny', 'or', 'la', 'wa', 'hi', 'ok', 'ms', 'nm',
#        'al'], dtype=object)

# %%
# Mostrar a lista de modelos únicos (opcional)
modelos_unicos = df["state"].unique()

print(f"Número total de modelos diferentes: {num_modelos}")
print("Lista de modelos únicos:")
print(modelos_unicos)
# Out:
# Número total de modelos diferentes: 64
# Lista de modelos únicos:
# ['ca' 'tx' 'pa' 'mn' 'az' 'wi' 'tn' 'md' 'fl' 'ne' 'nj' 'nv' 'oh' 'mi'
#  'ga' 'va' 'sc' 'nc' 'in' 'il' 'co' 'ut' 'mo' 'ny' 'ma' 'pr' 'or' 'la'
#  'wa' 'hi' 'qc' 'ab' 'on' 'ok' 'ms' 'nm' 'al']

# %%
import pandas as pd

# Carregar o ficheiro CSV
novo = pd.read_csv("car_prices_sem_na.csv")

# Remover colunas específicas
colunas_para_remover = ['Unnamed: 0','year', 'trim', 'body',  'transmission', 'vin', 'state', 'condition', 'odometer', 'color', 'interior', 'seller',"mmr"]
novo_novo = novo.drop(columns=colunas_para_remover)

# Exibir o DataFrame resultante
novo_novo
# Out:
#           make                model  sellingprice  \
# 0          Kia              Sorento       21500.0
# 1          Kia              Sorento       21500.0
# 2          BMW             3 Series       30000.0
# 3        Volvo                  S60       27750.0
# 4          BMW  6 Series Gran Coupe       67000.0
# ...        ...                  ...           ...
# 472320     BMW             5 Series       22800.0
# 472321     Ram                 2500       30800.0
# 472322     BMW                   X5       34000.0
# 472323  Nissan               Altima       11100.0
# 472324    Ford                F-150       26700.0
#
#                                        saledate
# 0       Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1       Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2       Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3       Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4       Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
# ...                                         ...
# ...
